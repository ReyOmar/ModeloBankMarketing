# %% [markdown]
# # 01 - Exploración
#
# Cuaderno inicial para explorar los datos y realizar visualizaciones.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print('imports OK')
